# %%
import pandas as pd
import numpy as np

#Series (rows)>>1d
#DatFrame(colums)>>2d

arr=pd.Series([1,2,3,4])  #>>>1d array (no columns)
arr
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
arr=pd.DataFrame([1,2,3,4])  #>>>2d Array (rows and col) & indexes are default
arr
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
arr=pd.DataFrame({"name":["prabhas","billa"],"age":[21,12],"grade":[8.8,9.5]})
arr
# Out:
#       name  age  grade
# 0  prabhas   21    8.8
# 1    billa   12    9.5

# %%
arr.index=["a","s"]    # Set Custom Index var.index=[list of num/ names]
print(arr)
# Out:
#       name  age  grade
# a  prabhas   21    8.8
# s    billa   12    9.5

# %%
arr.shape[1]    #df.shape[0] >>>no. of rows #df.shape[1] >>>no. of col
# Out:
# 3

# %%
arr1=arr.rename(columns={"name":"s_name","age":"s_age","grade":"s_garde"})
arr1
# Out:
#     s_name  s_age  s_garde
# a  prabhas     21      8.8
# s    billa     12      9.5

# %%
arr1=arr.rename(index={"a":"0","s":"1"})
arr1
# Out:
#       name  age  grade
# 0  prabhas   21    8.8
# 1    billa   12    9.5

# %%
arr.iloc[0]
# Out:
# name     prabhas
# age           21
# grade        8.8
# Name: a, dtype: object

# %%
print(arr.columns)     #syntax to print all col names of table
# Out:
# Index(['name', 'age', 'grade'], dtype='object')

# %%
print(arr.index)     #syntax to print all row names of table
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
import pandas as pd

df=pd.DataFrame({"name":["charan","cbg","pbk"],"ages":[23,25,55],"city":["hyd","delhi","mumbai"]})
df
# Out:
#      name  ages    city
# 0  charan    23     hyd
# 1     cbg    25   delhi
# 2     pbk    55  mumbai

# %%
# Set custom index
df.index=["c001","c002","c003"]
print(df)
# Out:
#       ages    city
# c001    23     hyd
# c002    25   delhi
# c003    55  mumbai

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["charan", "cbg", "pbk"],
    "ages": [23, 25, 55],
    "city": ["hyd", "delhi", "mumbai"]
})


df.index = ["c001", "c002", "c003"]

print(df)
# Out:
#         name  ages    city
# c001  charan    23     hyd
# c002     cbg    25   delhi
# c003     pbk    55  mumbai

# %%
import random
import numpy as np

ar=[[random.randint(1,30)],[random.randint(1,30)]]  #ar=[[],[]]>>>2d array
df=pd.DataFrame(ar)
df
# Out:
#     0
# 0  18
# 1   2

# %%
df.columns=["name"]
df
# Out:
#       name
# name    18
# age      2

# %%
df=pd.DataFrame()
df.columns=[{"name":["shiva","sunny","gayatri","pradeep","reshmi"],"age":[25,26,25,27,26],"hobby":["hyd","c","k","hyd","raj"]]}]
df
# Out:
#   Cell In[517], line 2
#     df.columns=[{"name":["shiva"]},axis=0]
#                                    ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [raw]
# ❌ Problem in Your Code:
#
# df.columns = [ { ... } ]
# This is not the right way to assign data to a DataFrame. You're trying to assign a dictionary inside a list to .columns, which is invalid.

# %%
df=pd.DataFrame()
df.columns=({"name":["shiva","sunny","gayatri","pradeep","reshmi"],"age":[25,26,25,27,26],"hobby":["hyd","c","k","hyd","raj"]})
            
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[521], line 2
#       1 df=pd.DataFrame()
# ----> 2 df.columns=({"name":["shiva","sunny","gayatri","pradeep","reshmi"],"age":[25,26,25,27,26],"hobby":["hyd","c","k","hyd","raj"]})
#       4 print(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 3 elements

# %%
# main types of operations


df.head()          # First 5 rows
df.tail()          # Last 5 rows
df.info()          # Summary of dataframe (columns, non-null counts, types)
df.describe()      # Statistics for numerical columns
df.columns         # List of column names
df.shape           # Rows and columns (rows, cols)
df.dtypes          # Data types of each column

# %% [markdown]
# #to import csv file
# >>>pd.read_csv(r"file name")  where r:unique value
#
#
# #simlarly to import excel file
# >>>pd.read_excel(r"file name")

# %%
df=pd.read_csv(r"C:\Users\91709\Downloads\ind_niftyEv_NewAgeAutomotive_list.csv")
df
# Out:
#                                 Company Name                        Industry  \
# 0          Amara Raja Energy & Mobility Ltd.  Automobile and Auto Components
# 1                         Ashok Leyland Ltd.                   Capital Goods
# 2                            Bajaj Auto Ltd.  Automobile and Auto Components
# 3                          Bharat Forge Ltd.  Automobile and Auto Components
# 4                                 Bosch Ltd.  Automobile and Auto Components
# 5     CG Power and Industrial Solutions Ltd.                   Capital Goods
# 6                         Eicher Motors Ltd.  Automobile and Auto Components
# 7                      Exide Industries Ltd.  Automobile and Auto Components
# 8               Gujarat Fluorochemicals Ltd.                       Chemicals
# 9                         Hero MotoCorp Ltd.  Automobile and Auto Components
# 10          Himadri Speciality Chemical Ltd.                       Chemicals
# 11                             JBM Auto Ltd.  Automobile and Auto Components
# 12                       Jupiter Wagons Ltd.                   Capital Goods
# 13                    KPIT Technologies Ltd.          Information Technology
# 14              L&T Technology Services Ltd.          Information Technology
# 15                  Mahindra & Mahindra Ltd.  Automobile and Auto Components
# 16                  Maruti Suzuki India Ltd.  Automobile and Auto Components
# 17                    Minda Corporation Ltd.  Automobile and Auto Components
# 18          Motherson Sumi Wiring India Ltd.  Automobile and Auto Components
# 19                    Olectra Greentech Ltd.  Automobile and Auto Components
# 20              RattanIndia Enterprises Ltd.               Consumer Services
# 21                  Reliance Industries Ltd.     Oil, Gas & Consumable Fuels
# 22  Samvardhana Motherson International Ltd.  Automobile and Auto Components
# 23                     Schaeffler India Ltd.  Automobile and Auto Components
# 24          Sona BLW Precision Forgings Ltd.  Automobile and Auto Components
# 25                    TVS Motor Company Ltd.  Automobile and Auto Components
# 26                       Tata Chemicals Ltd.                       Chemicals
# 27                           Tata Elxsi Ltd.          Information Technology
# 28                          Tata Motors Ltd.  Automobile and Auto Components
# 29                    Tata Technologies Ltd.          Information Technology
# 30            Tube Investments of India Ltd.  Automobile and Auto Components
# 31                            UNO Minda Ltd.  Automobile and Auto Components
# 32                   Varroc Engineering Ltd.  Automobile and Auto Components
#
#         Symbol Series     ISIN Code
# 0        ARE&M     EQ  INE885A01032
# 1     ASHOKLEY     EQ  INE208A01029
# 2   BAJAJ-AUTO     EQ  INE917I01010
# 3   BHARATFORG     EQ  INE465A01025
# 4     BOSCHLTD     EQ  INE323A01026
# 5      CGPOWER     EQ  INE067A01029
# 6    EICHERMOT     EQ  INE066A01021
# 7     EXIDEIND     EQ  INE302A01020
# 8   FLUOROCHEM     EQ  INE09N301011
# 9   HEROMOTOCO     EQ  INE158A01026
# 10        HSCL     EQ  INE019C01026
# 11        JBMA     EQ  INE927D01044
# 12         JWL     EQ  INE209L01016
# 13    KPITTECH     EQ  INE04I401011
# 14        LTTS     EQ  INE010V01017
# 15         M&M     EQ  INE101A01026
# 16      MARUTI     EQ  INE585B01010
# 17   MINDACORP     EQ  INE842C01021
# 18       MSUMI     EQ  INE0FS801015
# 19     OLECTRA     EQ  INE260D01016
# 20    RTNINDIA     EQ  INE834M01019
# 21    RELIANCE     EQ  INE002A01018
# 22   MOTHERSON     EQ  INE775A01035
# 23  SCHAEFFLER     EQ  INE513A01022
# 24    SONACOMS     EQ  INE073K01018
# 25    TVSMOTOR     EQ  INE494B01023
# 26    TATACHEM     EQ  INE092A01019
# 27   TATAELXSI     EQ  INE670A01012
# 28  TATAMOTORS     EQ  INE155A01022
# 29    TATATECH     EQ  INE142M01025
# 30     TIINDIA     EQ  INE974X01010
# 31    UNOMINDA     EQ  INE405E01023
# 32      VARROC     EQ  INE665L01035

# %%
df.shape[1]  #>>>no.of col
# Out:
# 5

# %%
df=df.rename(columns={"Industry":"ind_name","Symbol":"sym"})
df
# Out:
#                                 Company Name                        ind_name  \
# 0          Amara Raja Energy & Mobility Ltd.  Automobile and Auto Components
# 1                         Ashok Leyland Ltd.                   Capital Goods
# 2                            Bajaj Auto Ltd.  Automobile and Auto Components
# 3                          Bharat Forge Ltd.  Automobile and Auto Components
# 4                                 Bosch Ltd.  Automobile and Auto Components
# 5     CG Power and Industrial Solutions Ltd.                   Capital Goods
# 6                         Eicher Motors Ltd.  Automobile and Auto Components
# 7                      Exide Industries Ltd.  Automobile and Auto Components
# 8               Gujarat Fluorochemicals Ltd.                       Chemicals
# 9                         Hero MotoCorp Ltd.  Automobile and Auto Components
# 10          Himadri Speciality Chemical Ltd.                       Chemicals
# 11                             JBM Auto Ltd.  Automobile and Auto Components
# 12                       Jupiter Wagons Ltd.                   Capital Goods
# 13                    KPIT Technologies Ltd.          Information Technology
# 14              L&T Technology Services Ltd.          Information Technology
# 15                  Mahindra & Mahindra Ltd.  Automobile and Auto Components
# 16                  Maruti Suzuki India Ltd.  Automobile and Auto Components
# 17                    Minda Corporation Ltd.  Automobile and Auto Components
# 18          Motherson Sumi Wiring India Ltd.  Automobile and Auto Components
# 19                    Olectra Greentech Ltd.  Automobile and Auto Components
# 20              RattanIndia Enterprises Ltd.               Consumer Services
# 21                  Reliance Industries Ltd.     Oil, Gas & Consumable Fuels
# 22  Samvardhana Motherson International Ltd.  Automobile and Auto Components
# 23                     Schaeffler India Ltd.  Automobile and Auto Components
# 24          Sona BLW Precision Forgings Ltd.  Automobile and Auto Components
# 25                    TVS Motor Company Ltd.  Automobile and Auto Components
# 26                       Tata Chemicals Ltd.                       Chemicals
# 27                           Tata Elxsi Ltd.          Information Technology
# 28                          Tata Motors Ltd.  Automobile and Auto Components
# 29                    Tata Technologies Ltd.          Information Technology
# 30            Tube Investments of India Ltd.  Automobile and Auto Components
# 31                            UNO Minda Ltd.  Automobile and Auto Components
# 32                   Varroc Engineering Ltd.  Automobile and Auto Components
#
#            sym Series     ISIN Code
# 0        ARE&M     EQ  INE885A01032
# 1     ASHOKLEY     EQ  INE208A01029
# 2   BAJAJ-AUTO     EQ  INE917I01010
# 3   BHARATFORG     EQ  INE465A01025
# 4     BOSCHLTD     EQ  INE323A01026
# 5      CGPOWER     EQ  INE067A01029
# 6    EICHERMOT     EQ  INE066A01021
# 7     EXIDEIND     EQ  INE302A01020
# 8   FLUOROCHEM     EQ  INE09N301011
# 9   HEROMOTOCO     EQ  INE158A01026
# 10        HSCL     EQ  INE019C01026
# 11        JBMA     EQ  INE927D01044
# 12         JWL     EQ  INE209L01016
# 13    KPITTECH     EQ  INE04I401011
# 14        LTTS     EQ  INE010V01017
# 15         M&M     EQ  INE101A01026
# 16      MARUTI     EQ  INE585B01010
# 17   MINDACORP     EQ  INE842C01021
# 18       MSUMI     EQ  INE0FS801015
# 19     OLECTRA     EQ  INE260D01016
# 20    RTNINDIA     EQ  INE834M01019
# 21    RELIANCE     EQ  INE002A01018
# 22   MOTHERSON     EQ  INE775A01035
# 23  SCHAEFFLER     EQ  INE513A01022
# 24    SONACOMS     EQ  INE073K01018
# 25    TVSMOTOR     EQ  INE494B01023
# 26    TATACHEM     EQ  INE092A01019
# 27   TATAELXSI     EQ  INE670A01012
# 28  TATAMOTORS     EQ  INE155A01022
# 29    TATATECH     EQ  INE142M01025
# 30     TIINDIA     EQ  INE974X01010
# 31    UNOMINDA     EQ  INE405E01023
# 32      VARROC     EQ  INE665L01035

# %%
#variable.head() >>>returns 1st five columns

df.head()
# Out:
#                         Company Name                        ind_name  \
# 0  Amara Raja Energy & Mobility Ltd.  Automobile and Auto Components
# 1                 Ashok Leyland Ltd.                   Capital Goods
# 2                    Bajaj Auto Ltd.  Automobile and Auto Components
# 3                  Bharat Forge Ltd.  Automobile and Auto Components
# 4                         Bosch Ltd.  Automobile and Auto Components
#
#           sym Series     ISIN Code
# 0       ARE&M     EQ  INE885A01032
# 1    ASHOKLEY     EQ  INE208A01029
# 2  BAJAJ-AUTO     EQ  INE917I01010
# 3  BHARATFORG     EQ  INE465A01025
# 4    BOSCHLTD     EQ  INE323A01026

# %%
#variable.tail() >>>last five columns

# %%
df.tail()
# Out:
#                       Company Name                        ind_name  \
# 28                Tata Motors Ltd.  Automobile and Auto Components
# 29          Tata Technologies Ltd.          Information Technology
# 30  Tube Investments of India Ltd.  Automobile and Auto Components
# 31                  UNO Minda Ltd.  Automobile and Auto Components
# 32         Varroc Engineering Ltd.  Automobile and Auto Components
#
#            sym Series     ISIN Code
# 28  TATAMOTORS     EQ  INE155A01022
# 29    TATATECH     EQ  INE142M01025
# 30     TIINDIA     EQ  INE974X01010
# 31    UNOMINDA     EQ  INE405E01023
# 32      VARROC     EQ  INE665L01035

# %%
print(df.columns)
# Out:
# Index(['Company Name', 'ind_name', 'sym', 'Series', 'ISIN Code'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Company Name    object
# ind_name        object
# sym             object
# Series          object
# ISIN Code       object
# dtype: object

# %%
# main types of operations

df['ColumnName']            # Select a column
df[['Col1', 'Col2']]        # Select multiple columns
df.loc[0]                   # Select row by label/index
df.iloc[0]                  # Select row by integer index
df.iloc[0:5, 1:3]           # Select rows and columns by range

# %%
df.iloc[0:5,1:2]
# Out:
#                          ind_name
# 0  Automobile and Auto Components
# 1                   Capital Goods
# 2  Automobile and Auto Components
# 3  Automobile and Auto Components
# 4  Automobile and Auto Components

# %%
df.iloc[0]
# Out:
# Company Name    Amara Raja Energy & Mobility Ltd.
# ind_name           Automobile and Auto Components
# sym                                         ARE&M
# Series                                         EQ
# ISIN Code                            INE885A01032
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# Company Name    Amara Raja Energy & Mobility Ltd.
# ind_name           Automobile and Auto Components
# sym                                         ARE&M
# Series                                         EQ
# ISIN Code                            INE885A01032
# Name: 0, dtype: object

# %% [markdown]
#  3. Filtering / Conditions
#
# df[df['Age'] > 25]          # Filter rows where Age > 25
# df[(df['Age'] > 20) & (df['City'] == 'Delhi')]  # Multiple conditions
#
#
# ✏️ 4. Modifying Data
#
# df['NewCol'] = df['Age'] * 2      # Add new column
# df['City'] = df['City'].str.upper()  # Modify string data
# df.rename(columns={'Old': 'New'})  # Rename columns
# df.drop('Col', axis=1)             # Drop a column
#
#
# 🔢 5. Aggregation & Grouping
#
# df.groupby('City')['Age'].mean()    # Average age by city
# df['Age'].sum()                     # Total sum of Age
# df.value_counts('City')             # Count of values per city
# 🧹 6. Handling Missing Data
# python
# Copy
# Edit
# df.isnull().sum()                   # Count of missing values
# df.dropna()                         # Drop rows with any missing values
# df.fillna(0)                        # Fill missing values with 0
#
#
# 🔀 7. Sorting
#
# df.sort_values(by='Age')                     # Sort by Age
# df.sort_values(by='Age', ascending=False)    # Descending sort
#
# 📊 8. Visualization (optional using matplotlib/seaborn)
#
# import matplotlib.pyplot as plt
#
# df['Age'].hist()   # Histogram of Age
# plt.show()

# %%
""####🧠 Explanation:
df → your DataFrame

'Col' → the name of the column you want to drop

axis=1 → tells Pandas that you're dropping columns (not rows)

axis	 Meaning
0	   Drop a row
1	   Drop a column                                 """
# Out:
# "####🧠 Explanation:\ndf → your DataFrame\n\n'Col' → the name of the column you want to drop\n\naxis=1 → tells Pandas that you're dropping columns (not rows)\n\naxis\t Meaning\n0\t   Drop a row\n1\t   Drop a column"

# %%
df.drop("sym",axis=1)
# Out:
#                                 Company Name                        ind_name  \
# 0          Amara Raja Energy & Mobility Ltd.  Automobile and Auto Components
# 1                         Ashok Leyland Ltd.                   Capital Goods
# 2                            Bajaj Auto Ltd.  Automobile and Auto Components
# 3                          Bharat Forge Ltd.  Automobile and Auto Components
# 4                                 Bosch Ltd.  Automobile and Auto Components
# 5     CG Power and Industrial Solutions Ltd.                   Capital Goods
# 6                         Eicher Motors Ltd.  Automobile and Auto Components
# 7                      Exide Industries Ltd.  Automobile and Auto Components
# 8               Gujarat Fluorochemicals Ltd.                       Chemicals
# 9                         Hero MotoCorp Ltd.  Automobile and Auto Components
# 10          Himadri Speciality Chemical Ltd.                       Chemicals
# 11                             JBM Auto Ltd.  Automobile and Auto Components
# 12                       Jupiter Wagons Ltd.                   Capital Goods
# 13                    KPIT Technologies Ltd.          Information Technology
# 14              L&T Technology Services Ltd.          Information Technology
# 15                  Mahindra & Mahindra Ltd.  Automobile and Auto Components
# 16                  Maruti Suzuki India Ltd.  Automobile and Auto Components
# 17                    Minda Corporation Ltd.  Automobile and Auto Components
# 18          Motherson Sumi Wiring India Ltd.  Automobile and Auto Components
# 19                    Olectra Greentech Ltd.  Automobile and Auto Components
# 20              RattanIndia Enterprises Ltd.               Consumer Services
# 21                  Reliance Industries Ltd.     Oil, Gas & Consumable Fuels
# 22  Samvardhana Motherson International Ltd.  Automobile and Auto Components
# 23                     Schaeffler India Ltd.  Automobile and Auto Components
# 24          Sona BLW Precision Forgings Ltd.  Automobile and Auto Components
# 25                    TVS Motor Company Ltd.  Automobile and Auto Components
# 26                       Tata Chemicals Ltd.                       Chemicals
# 27                           Tata Elxsi Ltd.          Information Technology
# 28                          Tata Motors Ltd.  Automobile and Auto Components
# 29                    Tata Technologies Ltd.          Information Technology
# 30            Tube Investments of India Ltd.  Automobile and Auto Components
# 31                            UNO Minda Ltd.  Automobile and Auto Components
# 32                   Varroc Engineering Ltd.  Automobile and Auto Components
#
#    Series     ISIN Code
# 0      EQ  INE885A01032
# 1      EQ  INE208A01029
# 2      EQ  INE917I01010
# 3      EQ  INE465A01025
# 4      EQ  INE323A01026
# 5      EQ  INE067A01029
# 6      EQ  INE066A01021
# 7      EQ  INE302A01020
# 8      EQ  INE09N301011
# 9      EQ  INE158A01026
# 10     EQ  INE019C01026
# 11     EQ  INE927D01044
# 12     EQ  INE209L01016
# 13     EQ  INE04I401011
# 14     EQ  INE010V01017
# 15     EQ  INE101A01026
# 16     EQ  INE585B01010
# 17     EQ  INE842C01021
# 18     EQ  INE0FS801015
# 19     EQ  INE260D01016
# 20     EQ  INE834M01019
# 21     EQ  INE002A01018
# 22     EQ  INE775A01035
# 23     EQ  INE513A01022
# 24     EQ  INE073K01018
# 25     EQ  INE494B01023
# 26     EQ  INE092A01019
# 27     EQ  INE670A01012
# 28     EQ  INE155A01022
# 29     EQ  INE142M01025
# 30     EQ  INE974X01010
# 31     EQ  INE405E01023
# 32     EQ  INE665L01035

# %%
df.reset_index()   #restore the file with index numbers
# Out:
#     index                              Company Name  \
# 0       0         Amara Raja Energy & Mobility Ltd.
# 1       1                        Ashok Leyland Ltd.
# 2       2                           Bajaj Auto Ltd.
# 3       3                         Bharat Forge Ltd.
# 4       4                                Bosch Ltd.
# 5       5    CG Power and Industrial Solutions Ltd.
# 6       6                        Eicher Motors Ltd.
# 7       7                     Exide Industries Ltd.
# 8       8              Gujarat Fluorochemicals Ltd.
# 9       9                        Hero MotoCorp Ltd.
# 10     10          Himadri Speciality Chemical Ltd.
# 11     11                             JBM Auto Ltd.
# 12     12                       Jupiter Wagons Ltd.
# 13     13                    KPIT Technologies Ltd.
# 14     14              L&T Technology Services Ltd.
# 15     15                  Mahindra & Mahindra Ltd.
# 16     16                  Maruti Suzuki India Ltd.
# 17     17                    Minda Corporation Ltd.
# 18     18          Motherson Sumi Wiring India Ltd.
# 19     19                    Olectra Greentech Ltd.
# 20     20              RattanIndia Enterprises Ltd.
# 21     21                  Reliance Industries Ltd.
# 22     22  Samvardhana Motherson International Ltd.
# 23     23                     Schaeffler India Ltd.
# 24     24          Sona BLW Precision Forgings Ltd.
# 25     25                    TVS Motor Company Ltd.
# 26     26                       Tata Chemicals Ltd.
# 27     27                           Tata Elxsi Ltd.
# 28     28                          Tata Motors Ltd.
# 29     29                    Tata Technologies Ltd.
# 30     30            Tube Investments of India Ltd.
# 31     31                            UNO Minda Ltd.
# 32     32                   Varroc Engineering Ltd.
#
#                           ind_name         sym Series     ISIN Code
# 0   Automobile and Auto Components       ARE&M     EQ  INE885A01032
# 1                    Capital Goods    ASHOKLEY     EQ  INE208A01029
# 2   Automobile and Auto Components  BAJAJ-AUTO     EQ  INE917I01010
# 3   Automobile and Auto Components  BHARATFORG     EQ  INE465A01025
# 4   Automobile and Auto Components    BOSCHLTD     EQ  INE323A01026
# 5                    Capital Goods     CGPOWER     EQ  INE067A01029
# 6   Automobile and Auto Components   EICHERMOT     EQ  INE066A01021
# 7   Automobile and Auto Components    EXIDEIND     EQ  INE302A01020
# 8                        Chemicals  FLUOROCHEM     EQ  INE09N301011
# 9   Automobile and Auto Components  HEROMOTOCO     EQ  INE158A01026
# 10                       Chemicals        HSCL     EQ  INE019C01026
# 11  Automobile and Auto Components        JBMA     EQ  INE927D01044
# 12                   Capital Goods         JWL     EQ  INE209L01016
# 13          Information Technology    KPITTECH     EQ  INE04I401011
# 14          Information Technology        LTTS     EQ  INE010V01017
# 15  Automobile and Auto Components         M&M     EQ  INE101A01026
# 16  Automobile and Auto Components      MARUTI     EQ  INE585B01010
# 17  Automobile and Auto Components   MINDACORP     EQ  INE842C01021
# 18  Automobile and Auto Components       MSUMI     EQ  INE0FS801015
# 19  Automobile and Auto Components     OLECTRA     EQ  INE260D01016
# 20               Consumer Services    RTNINDIA     EQ  INE834M01019
# 21     Oil, Gas & Consumable Fuels    RELIANCE     EQ  INE002A01018
# 22  Automobile and Auto Components   MOTHERSON     EQ  INE775A01035
# 23  Automobile and Auto Components  SCHAEFFLER     EQ  INE513A01022
# 24  Automobile and Auto Components    SONACOMS     EQ  INE073K01018
# 25  Automobile and Auto Components    TVSMOTOR     EQ  INE494B01023
# 26                       Chemicals    TATACHEM     EQ  INE092A01019
# 27          Information Technology   TATAELXSI     EQ  INE670A01012
# 28  Automobile and Auto Components  TATAMOTORS     EQ  INE155A01022
# 29          Information Technology    TATATECH     EQ  INE142M01025
# 30  Automobile and Auto Components     TIINDIA     EQ  INE974X01010
# 31  Automobile and Auto Components    UNOMINDA     EQ  INE405E01023
# 32  Automobile and Auto Components      VARROC     EQ  INE665L01035

# %%
df.value_counts('ind_name')   # Count of values per ind_name
# Out:
# ind_name
# Automobile and Auto Components    21
# Information Technology             4
# Capital Goods                      3
# Chemicals                          3
# Consumer Services                  1
# Oil, Gas & Consumable Fuels        1
# Name: count, dtype: int64

# %%
df=df.rename(columns={"ind_name":"Industry"})  # Rename columns
df
# Out:
#                                 Company Name                        Industry  \
# 0          Amara Raja Energy & Mobility Ltd.  Automobile and Auto Components
# 1                         Ashok Leyland Ltd.                   Capital Goods
# 2                            Bajaj Auto Ltd.  Automobile and Auto Components
# 3                          Bharat Forge Ltd.  Automobile and Auto Components
# 4                                 Bosch Ltd.  Automobile and Auto Components
# 5     CG Power and Industrial Solutions Ltd.                   Capital Goods
# 6                         Eicher Motors Ltd.  Automobile and Auto Components
# 7                      Exide Industries Ltd.  Automobile and Auto Components
# 8               Gujarat Fluorochemicals Ltd.                       Chemicals
# 9                         Hero MotoCorp Ltd.  Automobile and Auto Components
# 10          Himadri Speciality Chemical Ltd.                       Chemicals
# 11                             JBM Auto Ltd.  Automobile and Auto Components
# 12                       Jupiter Wagons Ltd.                   Capital Goods
# 13                    KPIT Technologies Ltd.          Information Technology
# 14              L&T Technology Services Ltd.          Information Technology
# 15                  Mahindra & Mahindra Ltd.  Automobile and Auto Components
# 16                  Maruti Suzuki India Ltd.  Automobile and Auto Components
# 17                    Minda Corporation Ltd.  Automobile and Auto Components
# 18          Motherson Sumi Wiring India Ltd.  Automobile and Auto Components
# 19                    Olectra Greentech Ltd.  Automobile and Auto Components
# 20              RattanIndia Enterprises Ltd.               Consumer Services
# 21                  Reliance Industries Ltd.     Oil, Gas & Consumable Fuels
# 22  Samvardhana Motherson International Ltd.  Automobile and Auto Components
# 23                     Schaeffler India Ltd.  Automobile and Auto Components
# 24          Sona BLW Precision Forgings Ltd.  Automobile and Auto Components
# 25                    TVS Motor Company Ltd.  Automobile and Auto Components
# 26                       Tata Chemicals Ltd.                       Chemicals
# 27                           Tata Elxsi Ltd.          Information Technology
# 28                          Tata Motors Ltd.  Automobile and Auto Components
# 29                    Tata Technologies Ltd.          Information Technology
# 30            Tube Investments of India Ltd.  Automobile and Auto Components
# 31                            UNO Minda Ltd.  Automobile and Auto Components
# 32                   Varroc Engineering Ltd.  Automobile and Auto Components
#
#            sym Series     ISIN Code
# 0        ARE&M     EQ  INE885A01032
# 1     ASHOKLEY     EQ  INE208A01029
# 2   BAJAJ-AUTO     EQ  INE917I01010
# 3   BHARATFORG     EQ  INE465A01025
# 4     BOSCHLTD     EQ  INE323A01026
# 5      CGPOWER     EQ  INE067A01029
# 6    EICHERMOT     EQ  INE066A01021
# 7     EXIDEIND     EQ  INE302A01020
# 8   FLUOROCHEM     EQ  INE09N301011
# 9   HEROMOTOCO     EQ  INE158A01026
# 10        HSCL     EQ  INE019C01026
# 11        JBMA     EQ  INE927D01044
# 12         JWL     EQ  INE209L01016
# 13    KPITTECH     EQ  INE04I401011
# 14        LTTS     EQ  INE010V01017
# 15         M&M     EQ  INE101A01026
# 16      MARUTI     EQ  INE585B01010
# 17   MINDACORP     EQ  INE842C01021
# 18       MSUMI     EQ  INE0FS801015
# 19     OLECTRA     EQ  INE260D01016
# 20    RTNINDIA     EQ  INE834M01019
# 21    RELIANCE     EQ  INE002A01018
# 22   MOTHERSON     EQ  INE775A01035
# 23  SCHAEFFLER     EQ  INE513A01022
# 24    SONACOMS     EQ  INE073K01018
# 25    TVSMOTOR     EQ  INE494B01023
# 26    TATACHEM     EQ  INE092A01019
# 27   TATAELXSI     EQ  INE670A01012
# 28  TATAMOTORS     EQ  INE155A01022
# 29    TATATECH     EQ  INE142M01025
# 30     TIINDIA     EQ  INE974X01010
# 31    UNOMINDA     EQ  INE405E01023
# 32      VARROC     EQ  INE665L01035

# %% [markdown]
# df['NewCol'] = df['oldcol'] * 2      # Add new column

# %%
df["return"]=df["sym"]*9
df
# Out:
#                                 Company Name                        Industry  \
# 0          Amara Raja Energy & Mobility Ltd.  Automobile and Auto Components
# 1                         Ashok Leyland Ltd.                   Capital Goods
# 2                            Bajaj Auto Ltd.  Automobile and Auto Components
# 3                          Bharat Forge Ltd.  Automobile and Auto Components
# 4                                 Bosch Ltd.  Automobile and Auto Components
# 5     CG Power and Industrial Solutions Ltd.                   Capital Goods
# 6                         Eicher Motors Ltd.  Automobile and Auto Components
# 7                      Exide Industries Ltd.  Automobile and Auto Components
# 8               Gujarat Fluorochemicals Ltd.                       Chemicals
# 9                         Hero MotoCorp Ltd.  Automobile and Auto Components
# 10          Himadri Speciality Chemical Ltd.                       Chemicals
# 11                             JBM Auto Ltd.  Automobile and Auto Components
# 12                       Jupiter Wagons Ltd.                   Capital Goods
# 13                    KPIT Technologies Ltd.          Information Technology
# 14              L&T Technology Services Ltd.          Information Technology
# 15                  Mahindra & Mahindra Ltd.  Automobile and Auto Components
# 16                  Maruti Suzuki India Ltd.  Automobile and Auto Components
# 17                    Minda Corporation Ltd.  Automobile and Auto Components
# 18          Motherson Sumi Wiring India Ltd.  Automobile and Auto Components
# 19                    Olectra Greentech Ltd.  Automobile and Auto Components
# 20              RattanIndia Enterprises Ltd.               Consumer Services
# 21                  Reliance Industries Ltd.     Oil, Gas & Consumable Fuels
# 22  Samvardhana Motherson International Ltd.  Automobile and Auto Components
# 23                     Schaeffler India Ltd.  Automobile and Auto Components
# 24          Sona BLW Precision Forgings Ltd.  Automobile and Auto Components
# 25                    TVS Motor Company Ltd.  Automobile and Auto Components
# 26                       Tata Chemicals Ltd.                       Chemicals
# 27                           Tata Elxsi Ltd.          Information Technology
# 28                          Tata Motors Ltd.  Automobile and Auto Components
# 29                    Tata Technologies Ltd.          Information Technology
# 30            Tube Investments of India Ltd.  Automobile and Auto Components
# 31                            UNO Minda Ltd.  Automobile and Auto Components
# 32                   Varroc Engineering Ltd.  Automobile and Auto Components
#
#            sym Series     ISIN Code  \
# 0        ARE&M     EQ  INE885A01032
# 1     ASHOKLEY     EQ  INE208A01029
# 2   BAJAJ-AUTO     EQ  INE917I01010
# 3   BHARATFORG     EQ  INE465A01025
# 4     BOSCHLTD     EQ  INE323A01026
# 5      CGPOWER     EQ  INE067A01029
# 6    EICHERMOT     EQ  INE066A01021
# 7     EXIDEIND     EQ  INE302A01020
# 8   FLUOROCHEM     EQ  INE09N301011
# 9   HEROMOTOCO     EQ  INE158A01026
# 10        HSCL     EQ  INE019C01026
# 11        JBMA     EQ  INE927D01044
# 12         JWL     EQ  INE209L01016
# 13    KPITTECH     EQ  INE04I401011
# 14        LTTS     EQ  INE010V01017
# 15         M&M     EQ  INE101A01026
# 16      MARUTI     EQ  INE585B01010
# 17   MINDACORP     EQ  INE842C01021
# 18       MSUMI     EQ  INE0FS801015
# 19     OLECTRA     EQ  INE260D01016
# 20    RTNINDIA     EQ  INE834M01019
# 21    RELIANCE     EQ  INE002A01018
# 22   MOTHERSON     EQ  INE775A01035
# 23  SCHAEFFLER     EQ  INE513A01022
# 24    SONACOMS     EQ  INE073K01018
# 25    TVSMOTOR     EQ  INE494B01023
# 26    TATACHEM     EQ  INE092A01019
# 27   TATAELXSI     EQ  INE670A01012
# 28  TATAMOTORS     EQ  INE155A01022
# 29    TATATECH     EQ  INE142M01025
# 30     TIINDIA     EQ  INE974X01010
# 31    UNOMINDA     EQ  INE405E01023
# 32      VARROC     EQ  INE665L01035
#
#                                                return
# 0       ARE&MARE&MARE&MARE&MARE&MARE&MARE&MARE&MARE&M
# 1   ASHOKLEYASHOKLEYASHOKLEYASHOKLEYASHOKLEYASHOKL...
# 2   BAJAJ-AUTOBAJAJ-AUTOBAJAJ-AUTOBAJAJ-AUTOBAJAJ-...
# 3   BHARATFORGBHARATFORGBHARATFORGBHARATFORGBHARAT...
# 4   BOSCHLTDBOSCHLTDBOSCHLTDBOSCHLTDBOSCHLTDBOSCHL...
# 5   CGPOWERCGPOWERCGPOWERCGPOWERCGPOWERCGPOWERCGPO...
# 6   EICHERMOTEICHERMOTEICHERMOTEICHERMOTEICHERMOTE...
# 7   EXIDEINDEXIDEINDEXIDEINDEXIDEINDEXIDEINDEXIDEI...
# 8   FLUOROCHEMFLUOROCHEMFLUOROCHEMFLUOROCHEMFLUORO...
# 9   HEROMOTOCOHEROMOTOCOHEROMOTOCOHEROMOTOCOHEROMO...
# 10               HSCLHSCLHSCLHSCLHSCLHSCLHSCLHSCLHSCL
# 11               JBMAJBMAJBMAJBMAJBMAJBMAJBMAJBMAJBMA
# 12                        JWLJWLJWLJWLJWLJWLJWLJWLJWL
# 13  KPITTECHKPITTECHKPITTECHKPITTECHKPITTECHKPITTE...
# 14               LTTSLTTSLTTSLTTSLTTSLTTSLTTSLTTSLTTS
# 15                        M&MM&MM&MM&MM&MM&MM&MM&MM&M
# 16  MARUTIMARUTIMARUTIMARUTIMARUTIMARUTIMARUTIMARU...
# 17  MINDACORPMINDACORPMINDACORPMINDACORPMINDACORPM...
# 18      MSUMIMSUMIMSUMIMSUMIMSUMIMSUMIMSUMIMSUMIMSUMI
# 19  OLECTRAOLECTRAOLECTRAOLECTRAOLECTRAOLECTRAOLEC...
# 20  RTNINDIARTNINDIARTNINDIARTNINDIARTNINDIARTNIND...
# 21  RELIANCERELIANCERELIANCERELIANCERELIANCERELIAN...
# 22  MOTHERSONMOTHERSONMOTHERSONMOTHERSONMOTHERSONM...
# 23  SCHAEFFLERSCHAEFFLERSCHAEFFLERSCHAEFFLERSCHAEF...
# 24  SONACOMSSONACOMSSONACOMSSONACOMSSONACOMSSONACO...
# 25  TVSMOTORTVSMOTORTVSMOTORTVSMOTORTVSMOTORTVSMOT...
# 26  TATACHEMTATACHEMTATACHEMTATACHEMTATACHEMTATACH...
# 27  TATAELXSITATAELXSITATAELXSITATAELXSITATAELXSIT...
# 28  TATAMOTORSTATAMOTORSTATAMOTORSTATAMOTORSTATAMO...
# 29  TATATECHTATATECHTATATECHTATATECHTATATECHTATATE...
# 30  TIINDIATIINDIATIINDIATIINDIATIINDIATIINDIATIIN...
# 31  UNOMINDAUNOMINDAUNOMINDAUNOMINDAUNOMINDAUNOMIN...
# 32  VARROCVARROCVARROCVARROCVARROCVARROCVARROCVARR...

# %%
df["sym"]
# Out:
# 0          ARE&M
# 1       ASHOKLEY
# 2     BAJAJ-AUTO
# 3     BHARATFORG
# 4       BOSCHLTD
# 5        CGPOWER
# 6      EICHERMOT
# 7       EXIDEIND
# 8     FLUOROCHEM
# 9     HEROMOTOCO
# 10          HSCL
# 11          JBMA
# 12           JWL
# 13      KPITTECH
# 14          LTTS
# 15           M&M
# 16        MARUTI
# 17     MINDACORP
# 18         MSUMI
# 19       OLECTRA
# 20      RTNINDIA
# 21      RELIANCE
# 22     MOTHERSON
# 23    SCHAEFFLER
# 24      SONACOMS
# 25      TVSMOTOR
# 26      TATACHEM
# 27     TATAELXSI
# 28    TATAMOTORS
# 29      TATATECH
# 30       TIINDIA
# 31      UNOMINDA
# 32        VARROC
# Name: sym, dtype: object

# %%
df.drop("return",axis=1)    #or df.drop(columns="return")
# Out:
#                                 Company Name                        Industry  \
# 0          Amara Raja Energy & Mobility Ltd.  Automobile and Auto Components
# 1                         Ashok Leyland Ltd.                   Capital Goods
# 2                            Bajaj Auto Ltd.  Automobile and Auto Components
# 3                          Bharat Forge Ltd.  Automobile and Auto Components
# 4                                 Bosch Ltd.  Automobile and Auto Components
# 5     CG Power and Industrial Solutions Ltd.                   Capital Goods
# 6                         Eicher Motors Ltd.  Automobile and Auto Components
# 7                      Exide Industries Ltd.  Automobile and Auto Components
# 8               Gujarat Fluorochemicals Ltd.                       Chemicals
# 9                         Hero MotoCorp Ltd.  Automobile and Auto Components
# 10          Himadri Speciality Chemical Ltd.                       Chemicals
# 11                             JBM Auto Ltd.  Automobile and Auto Components
# 12                       Jupiter Wagons Ltd.                   Capital Goods
# 13                    KPIT Technologies Ltd.          Information Technology
# 14              L&T Technology Services Ltd.          Information Technology
# 15                  Mahindra & Mahindra Ltd.  Automobile and Auto Components
# 16                  Maruti Suzuki India Ltd.  Automobile and Auto Components
# 17                    Minda Corporation Ltd.  Automobile and Auto Components
# 18          Motherson Sumi Wiring India Ltd.  Automobile and Auto Components
# 19                    Olectra Greentech Ltd.  Automobile and Auto Components
# 20              RattanIndia Enterprises Ltd.               Consumer Services
# 21                  Reliance Industries Ltd.     Oil, Gas & Consumable Fuels
# 22  Samvardhana Motherson International Ltd.  Automobile and Auto Components
# 23                     Schaeffler India Ltd.  Automobile and Auto Components
# 24          Sona BLW Precision Forgings Ltd.  Automobile and Auto Components
# 25                    TVS Motor Company Ltd.  Automobile and Auto Components
# 26                       Tata Chemicals Ltd.                       Chemicals
# 27                           Tata Elxsi Ltd.          Information Technology
# 28                          Tata Motors Ltd.  Automobile and Auto Components
# 29                    Tata Technologies Ltd.          Information Technology
# 30            Tube Investments of India Ltd.  Automobile and Auto Components
# 31                            UNO Minda Ltd.  Automobile and Auto Components
# 32                   Varroc Engineering Ltd.  Automobile and Auto Components
#
#            sym Series     ISIN Code
# 0        ARE&M     EQ  INE885A01032
# 1     ASHOKLEY     EQ  INE208A01029
# 2   BAJAJ-AUTO     EQ  INE917I01010
# 3   BHARATFORG     EQ  INE465A01025
# 4     BOSCHLTD     EQ  INE323A01026
# 5      CGPOWER     EQ  INE067A01029
# 6    EICHERMOT     EQ  INE066A01021
# 7     EXIDEIND     EQ  INE302A01020
# 8   FLUOROCHEM     EQ  INE09N301011
# 9   HEROMOTOCO     EQ  INE158A01026
# 10        HSCL     EQ  INE019C01026
# 11        JBMA     EQ  INE927D01044
# 12         JWL     EQ  INE209L01016
# 13    KPITTECH     EQ  INE04I401011
# 14        LTTS     EQ  INE010V01017
# 15         M&M     EQ  INE101A01026
# 16      MARUTI     EQ  INE585B01010
# 17   MINDACORP     EQ  INE842C01021
# 18       MSUMI     EQ  INE0FS801015
# 19     OLECTRA     EQ  INE260D01016
# 20    RTNINDIA     EQ  INE834M01019
# 21    RELIANCE     EQ  INE002A01018
# 22   MOTHERSON     EQ  INE775A01035
# 23  SCHAEFFLER     EQ  INE513A01022
# 24    SONACOMS     EQ  INE073K01018
# 25    TVSMOTOR     EQ  INE494B01023
# 26    TATACHEM     EQ  INE092A01019
# 27   TATAELXSI     EQ  INE670A01012
# 28  TATAMOTORS     EQ  INE155A01022
# 29    TATATECH     EQ  INE142M01025
# 30     TIINDIA     EQ  INE974X01010
# 31    UNOMINDA     EQ  INE405E01023
# 32      VARROC     EQ  INE665L01035

# %%
df.value_counts('Series')
# Out:
# Series
# EQ    33
# Name: count, dtype: int64

# %%
df.isnull().sum()    # Count of missing values
# Out:
# Company Name    0
# Industry        0
# sym             0
# Series          0
# ISIN Code       0
# return          0
# dtype: int64

# %%
df.fillna(0)  # Fill missing values with 0
# Out:
#                                 Company Name                        Industry  \
# 0          Amara Raja Energy & Mobility Ltd.  Automobile and Auto Components
# 1                         Ashok Leyland Ltd.                   Capital Goods
# 2                            Bajaj Auto Ltd.  Automobile and Auto Components
# 3                          Bharat Forge Ltd.  Automobile and Auto Components
# 4                                 Bosch Ltd.  Automobile and Auto Components
# 5     CG Power and Industrial Solutions Ltd.                   Capital Goods
# 6                         Eicher Motors Ltd.  Automobile and Auto Components
# 7                      Exide Industries Ltd.  Automobile and Auto Components
# 8               Gujarat Fluorochemicals Ltd.                       Chemicals
# 9                         Hero MotoCorp Ltd.  Automobile and Auto Components
# 10          Himadri Speciality Chemical Ltd.                       Chemicals
# 11                             JBM Auto Ltd.  Automobile and Auto Components
# 12                       Jupiter Wagons Ltd.                   Capital Goods
# 13                    KPIT Technologies Ltd.          Information Technology
# 14              L&T Technology Services Ltd.          Information Technology
# 15                  Mahindra & Mahindra Ltd.  Automobile and Auto Components
# 16                  Maruti Suzuki India Ltd.  Automobile and Auto Components
# 17                    Minda Corporation Ltd.  Automobile and Auto Components
# 18          Motherson Sumi Wiring India Ltd.  Automobile and Auto Components
# 19                    Olectra Greentech Ltd.  Automobile and Auto Components
# 20              RattanIndia Enterprises Ltd.               Consumer Services
# 21                  Reliance Industries Ltd.     Oil, Gas & Consumable Fuels
# 22  Samvardhana Motherson International Ltd.  Automobile and Auto Components
# 23                     Schaeffler India Ltd.  Automobile and Auto Components
# 24          Sona BLW Precision Forgings Ltd.  Automobile and Auto Components
# 25                    TVS Motor Company Ltd.  Automobile and Auto Components
# 26                       Tata Chemicals Ltd.                       Chemicals
# 27                           Tata Elxsi Ltd.          Information Technology
# 28                          Tata Motors Ltd.  Automobile and Auto Components
# 29                    Tata Technologies Ltd.          Information Technology
# 30            Tube Investments of India Ltd.  Automobile and Auto Components
# 31                            UNO Minda Ltd.  Automobile and Auto Components
# 32                   Varroc Engineering Ltd.  Automobile and Auto Components
#
#            sym Series     ISIN Code  \
# 0        ARE&M     EQ  INE885A01032
# 1     ASHOKLEY     EQ  INE208A01029
# 2   BAJAJ-AUTO     EQ  INE917I01010
# 3   BHARATFORG     EQ  INE465A01025
# 4     BOSCHLTD     EQ  INE323A01026
# 5      CGPOWER     EQ  INE067A01029
# 6    EICHERMOT     EQ  INE066A01021
# 7     EXIDEIND     EQ  INE302A01020
# 8   FLUOROCHEM     EQ  INE09N301011
# 9   HEROMOTOCO     EQ  INE158A01026
# 10        HSCL     EQ  INE019C01026
# 11        JBMA     EQ  INE927D01044
# 12         JWL     EQ  INE209L01016
# 13    KPITTECH     EQ  INE04I401011
# 14        LTTS     EQ  INE010V01017
# 15         M&M     EQ  INE101A01026
# 16      MARUTI     EQ  INE585B01010
# 17   MINDACORP     EQ  INE842C01021
# 18       MSUMI     EQ  INE0FS801015
# 19     OLECTRA     EQ  INE260D01016
# 20    RTNINDIA     EQ  INE834M01019
# 21    RELIANCE     EQ  INE002A01018
# 22   MOTHERSON     EQ  INE775A01035
# 23  SCHAEFFLER     EQ  INE513A01022
# 24    SONACOMS     EQ  INE073K01018
# 25    TVSMOTOR     EQ  INE494B01023
# 26    TATACHEM     EQ  INE092A01019
# 27   TATAELXSI     EQ  INE670A01012
# 28  TATAMOTORS     EQ  INE155A01022
# 29    TATATECH     EQ  INE142M01025
# 30     TIINDIA     EQ  INE974X01010
# 31    UNOMINDA     EQ  INE405E01023
# 32      VARROC     EQ  INE665L01035
#
#                                                return
# 0       ARE&MARE&MARE&MARE&MARE&MARE&MARE&MARE&MARE&M
# 1   ASHOKLEYASHOKLEYASHOKLEYASHOKLEYASHOKLEYASHOKL...
# 2   BAJAJ-AUTOBAJAJ-AUTOBAJAJ-AUTOBAJAJ-AUTOBAJAJ-...
# 3   BHARATFORGBHARATFORGBHARATFORGBHARATFORGBHARAT...
# 4   BOSCHLTDBOSCHLTDBOSCHLTDBOSCHLTDBOSCHLTDBOSCHL...
# 5   CGPOWERCGPOWERCGPOWERCGPOWERCGPOWERCGPOWERCGPO...
# 6   EICHERMOTEICHERMOTEICHERMOTEICHERMOTEICHERMOTE...
# 7   EXIDEINDEXIDEINDEXIDEINDEXIDEINDEXIDEINDEXIDEI...
# 8   FLUOROCHEMFLUOROCHEMFLUOROCHEMFLUOROCHEMFLUORO...
# 9   HEROMOTOCOHEROMOTOCOHEROMOTOCOHEROMOTOCOHEROMO...
# 10               HSCLHSCLHSCLHSCLHSCLHSCLHSCLHSCLHSCL
# 11               JBMAJBMAJBMAJBMAJBMAJBMAJBMAJBMAJBMA
# 12                        JWLJWLJWLJWLJWLJWLJWLJWLJWL
# 13  KPITTECHKPITTECHKPITTECHKPITTECHKPITTECHKPITTE...
# 14               LTTSLTTSLTTSLTTSLTTSLTTSLTTSLTTSLTTS
# 15                        M&MM&MM&MM&MM&MM&MM&MM&MM&M
# 16  MARUTIMARUTIMARUTIMARUTIMARUTIMARUTIMARUTIMARU...
# 17  MINDACORPMINDACORPMINDACORPMINDACORPMINDACORPM...
# 18      MSUMIMSUMIMSUMIMSUMIMSUMIMSUMIMSUMIMSUMIMSUMI
# 19  OLECTRAOLECTRAOLECTRAOLECTRAOLECTRAOLECTRAOLEC...
# 20  RTNINDIARTNINDIARTNINDIARTNINDIARTNINDIARTNIND...
# 21  RELIANCERELIANCERELIANCERELIANCERELIANCERELIAN...
# 22  MOTHERSONMOTHERSONMOTHERSONMOTHERSONMOTHERSONM...
# 23  SCHAEFFLERSCHAEFFLERSCHAEFFLERSCHAEFFLERSCHAEF...
# 24  SONACOMSSONACOMSSONACOMSSONACOMSSONACOMSSONACO...
# 25  TVSMOTORTVSMOTORTVSMOTORTVSMOTORTVSMOTORTVSMOT...
# 26  TATACHEMTATACHEMTATACHEMTATACHEMTATACHEMTATACH...
# 27  TATAELXSITATAELXSITATAELXSITATAELXSITATAELXSIT...
# 28  TATAMOTORSTATAMOTORSTATAMOTORSTATAMOTORSTATAMO...
# 29  TATATECHTATATECHTATATECHTATATECHTATATECHTATATE...
# 30  TIINDIATIINDIATIINDIATIINDIATIINDIATIINDIATIIN...
# 31  UNOMINDAUNOMINDAUNOMINDAUNOMINDAUNOMINDAUNOMIN...
# 32  VARROCVARROCVARROCVARROCVARROCVARROCVARROCVARR...

# %%
df.sort_values(by="sym",ascending=False)
# Out:
#                                 Company Name                        Industry  \
# 32                   Varroc Engineering Ltd.  Automobile and Auto Components
# 31                            UNO Minda Ltd.  Automobile and Auto Components
# 25                    TVS Motor Company Ltd.  Automobile and Auto Components
# 30            Tube Investments of India Ltd.  Automobile and Auto Components
# 29                    Tata Technologies Ltd.          Information Technology
# 28                          Tata Motors Ltd.  Automobile and Auto Components
# 27                           Tata Elxsi Ltd.          Information Technology
# 26                       Tata Chemicals Ltd.                       Chemicals
# 24          Sona BLW Precision Forgings Ltd.  Automobile and Auto Components
# 23                     Schaeffler India Ltd.  Automobile and Auto Components
# 20              RattanIndia Enterprises Ltd.               Consumer Services
# 21                  Reliance Industries Ltd.     Oil, Gas & Consumable Fuels
# 19                    Olectra Greentech Ltd.  Automobile and Auto Components
# 18          Motherson Sumi Wiring India Ltd.  Automobile and Auto Components
# 22  Samvardhana Motherson International Ltd.  Automobile and Auto Components
# 17                    Minda Corporation Ltd.  Automobile and Auto Components
# 16                  Maruti Suzuki India Ltd.  Automobile and Auto Components
# 15                  Mahindra & Mahindra Ltd.  Automobile and Auto Components
# 14              L&T Technology Services Ltd.          Information Technology
# 13                    KPIT Technologies Ltd.          Information Technology
# 12                       Jupiter Wagons Ltd.                   Capital Goods
# 11                             JBM Auto Ltd.  Automobile and Auto Components
# 10          Himadri Speciality Chemical Ltd.                       Chemicals
# 9                         Hero MotoCorp Ltd.  Automobile and Auto Components
# 8               Gujarat Fluorochemicals Ltd.                       Chemicals
# 7                      Exide Industries Ltd.  Automobile and Auto Components
# 6                         Eicher Motors Ltd.  Automobile and Auto Components
# 5     CG Power and Industrial Solutions Ltd.                   Capital Goods
# 4                                 Bosch Ltd.  Automobile and Auto Components
# 3                          Bharat Forge Ltd.  Automobile and Auto Components
# 2                            Bajaj Auto Ltd.  Automobile and Auto Components
# 1                         Ashok Leyland Ltd.                   Capital Goods
# 0          Amara Raja Energy & Mobility Ltd.  Automobile and Auto Components
#
#            sym Series     ISIN Code  \
# 32      VARROC     EQ  INE665L01035
# 31    UNOMINDA     EQ  INE405E01023
# 25    TVSMOTOR     EQ  INE494B01023
# 30     TIINDIA     EQ  INE974X01010
# 29    TATATECH     EQ  INE142M01025
# 28  TATAMOTORS     EQ  INE155A01022
# 27   TATAELXSI     EQ  INE670A01012
# 26    TATACHEM     EQ  INE092A01019
# 24    SONACOMS     EQ  INE073K01018
# 23  SCHAEFFLER     EQ  INE513A01022
# 20    RTNINDIA     EQ  INE834M01019
# 21    RELIANCE     EQ  INE002A01018
# 19     OLECTRA     EQ  INE260D01016
# 18       MSUMI     EQ  INE0FS801015
# 22   MOTHERSON     EQ  INE775A01035
# 17   MINDACORP     EQ  INE842C01021
# 16      MARUTI     EQ  INE585B01010
# 15         M&M     EQ  INE101A01026
# 14        LTTS     EQ  INE010V01017
# 13    KPITTECH     EQ  INE04I401011
# 12         JWL     EQ  INE209L01016
# 11        JBMA     EQ  INE927D01044
# 10        HSCL     EQ  INE019C01026
# 9   HEROMOTOCO     EQ  INE158A01026
# 8   FLUOROCHEM     EQ  INE09N301011
# 7     EXIDEIND     EQ  INE302A01020
# 6    EICHERMOT     EQ  INE066A01021
# 5      CGPOWER     EQ  INE067A01029
# 4     BOSCHLTD     EQ  INE323A01026
# 3   BHARATFORG     EQ  INE465A01025
# 2   BAJAJ-AUTO     EQ  INE917I01010
# 1     ASHOKLEY     EQ  INE208A01029
# 0        ARE&M     EQ  INE885A01032
#
#                                                return
# 32  VARROCVARROCVARROCVARROCVARROCVARROCVARROCVARR...
# 31  UNOMINDAUNOMINDAUNOMINDAUNOMINDAUNOMINDAUNOMIN...
# 25  TVSMOTORTVSMOTORTVSMOTORTVSMOTORTVSMOTORTVSMOT...
# 30  TIINDIATIINDIATIINDIATIINDIATIINDIATIINDIATIIN...
# 29  TATATECHTATATECHTATATECHTATATECHTATATECHTATATE...
# 28  TATAMOTORSTATAMOTORSTATAMOTORSTATAMOTORSTATAMO...
# 27  TATAELXSITATAELXSITATAELXSITATAELXSITATAELXSIT...
# 26  TATACHEMTATACHEMTATACHEMTATACHEMTATACHEMTATACH...
# 24  SONACOMSSONACOMSSONACOMSSONACOMSSONACOMSSONACO...
# 23  SCHAEFFLERSCHAEFFLERSCHAEFFLERSCHAEFFLERSCHAEF...
# 20  RTNINDIARTNINDIARTNINDIARTNINDIARTNINDIARTNIND...
# 21  RELIANCERELIANCERELIANCERELIANCERELIANCERELIAN...
# 19  OLECTRAOLECTRAOLECTRAOLECTRAOLECTRAOLECTRAOLEC...
# 18      MSUMIMSUMIMSUMIMSUMIMSUMIMSUMIMSUMIMSUMIMSUMI
# 22  MOTHERSONMOTHERSONMOTHERSONMOTHERSONMOTHERSONM...
# 17  MINDACORPMINDACORPMINDACORPMINDACORPMINDACORPM...
# 16  MARUTIMARUTIMARUTIMARUTIMARUTIMARUTIMARUTIMARU...
# 15                        M&MM&MM&MM&MM&MM&MM&MM&MM&M
# 14               LTTSLTTSLTTSLTTSLTTSLTTSLTTSLTTSLTTS
# 13  KPITTECHKPITTECHKPITTECHKPITTECHKPITTECHKPITTE...
# 12                        JWLJWLJWLJWLJWLJWLJWLJWLJWL
# 11               JBMAJBMAJBMAJBMAJBMAJBMAJBMAJBMAJBMA
# 10               HSCLHSCLHSCLHSCLHSCLHSCLHSCLHSCLHSCL
# 9   HEROMOTOCOHEROMOTOCOHEROMOTOCOHEROMOTOCOHEROMO...
# 8   FLUOROCHEMFLUOROCHEMFLUOROCHEMFLUOROCHEMFLUORO...
# 7   EXIDEINDEXIDEINDEXIDEINDEXIDEINDEXIDEINDEXIDEI...
# 6   EICHERMOTEICHERMOTEICHERMOTEICHERMOTEICHERMOTE...
# 5   CGPOWERCGPOWERCGPOWERCGPOWERCGPOWERCGPOWERCGPO...
# 4   BOSCHLTDBOSCHLTDBOSCHLTDBOSCHLTDBOSCHLTDBOSCHL...
# 3   BHARATFORGBHARATFORGBHARATFORGBHARATFORGBHARAT...
# 2   BAJAJ-AUTOBAJAJ-AUTOBAJAJ-AUTOBAJAJ-AUTOBAJAJ-...
# 1   ASHOKLEYASHOKLEYASHOKLEYASHOKLEYASHOKLEYASHOKL...
# 0       ARE&MARE&MARE&MARE&MARE&MARE&MARE&MARE&MARE&M

# %%
import matplotlib.pyplot as plt
df["Industry"].hist()  # Histogram of Industry
plt.show()

# %%
df.value_counts("Industry") # Count of values per Industry
# Out:
# Industry
# Automobile and Auto Components    21
# Information Technology             4
# Capital Goods                      3
# Chemicals                          3
# Consumer Services                  1
# Oil, Gas & Consumable Fuels        1
# Name: count, dtype: int64

# %%
df.isnull().sum()     # Count of missing values
# Out:
# Company Name    0
# Industry        0
# sym             0
# Series          0
# ISIN Code       0
# return          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 0 to 32
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  33 non-null     object
#  1   Industry      33 non-null     object
#  2   sym           33 non-null     object
#  3   Series        33 non-null     object
#  4   ISIN Code     33 non-null     object
#  5   return        33 non-null     object
# dtypes: object(6)
# memory usage: 1.8+ KB
